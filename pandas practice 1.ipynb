# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Benura2020/ML_Practice_Projects/main/train.csv")

# %%
data
# Out:
#               date  store  item  sales
# 0       2013-01-01      1     1     13
# 1       2013-01-02      1     1     11
# 2       2013-01-03      1     1     14
# 3       2013-01-04      1     1     13
# 4       2013-01-05      1     1     10
# ...            ...    ...   ...    ...
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82
#
# [913000 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...

# %%
data = pd.read_csv(r"D:\Practice\ML Projects\Sales Smitha\train.csv")
data
# Out:
#               date  store  item  sales
# 0       2013-01-01      1     1     13
# 1       2013-01-02      1     1     11
# 2       2013-01-03      1     1     14
# 3       2013-01-04      1     1     13
# 4       2013-01-05      1     1     10
# ...            ...    ...   ...    ...
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82
#
# [913000 rows x 4 columns]

# %%
data.shape
# Out:
# (913000, 4)

# %%
data.count()
# Out:
# date     913000
# store    913000
# item     913000
# sales    913000
# dtype: int64

# %%
data.head(20)
# Out:
#           date  store  item  sales
# 0   2013-01-01      1     1     13
# 1   2013-01-02      1     1     11
# 2   2013-01-03      1     1     14
# 3   2013-01-04      1     1     13
# 4   2013-01-05      1     1     10
# 5   2013-01-06      1     1     12
# 6   2013-01-07      1     1     10
# 7   2013-01-08      1     1      9
# 8   2013-01-09      1     1     12
# 9   2013-01-10      1     1      9
# 10  2013-01-11      1     1      9
# 11  2013-01-12      1     1      7
# 12  2013-01-13      1     1     10
# 13  2013-01-14      1     1     12
# 14  2013-01-15      1     1      5
# 15  2013-01-16      1     1      7
# 16  2013-01-17      1     1     16
# 17  2013-01-18      1     1      7
# 18  2013-01-19      1     1     18
# 19  2013-01-20      1     1     15

# %%
condition = data["sales"]>10
filter = data[condition]
filter
# Out:
#               date  store  item  sales
# 0       2013-01-01      1     1     13
# 1       2013-01-02      1     1     11
# 2       2013-01-03      1     1     14
# 3       2013-01-04      1     1     13
# 5       2013-01-06      1     1     12
# ...            ...    ...   ...    ...
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82
#
# [901668 rows x 4 columns]

# %%
filter[["date", "store"]]
# Out:
#               date  store
# 0       2013-01-01      1
# 1       2013-01-02      1
# 2       2013-01-03      1
# 3       2013-01-04      1
# 5       2013-01-06      1
# ...            ...    ...
# 912995  2017-12-27     10
# 912996  2017-12-28     10
# 912997  2017-12-29     10
# 912998  2017-12-30     10
# 912999  2017-12-31     10
#
# [901668 rows x 2 columns]

# %%
condition = (data["sales"]>10) | (data["sales"]<2)
filter = data[condition]
filter[["date", "store"]]
# Out:
#               date  store
# 0       2013-01-01      1
# 1       2013-01-02      1
# 2       2013-01-03      1
# 3       2013-01-04      1
# 5       2013-01-06      1
# ...            ...    ...
# 912995  2017-12-27     10
# 912996  2017-12-28     10
# 912997  2017-12-29     10
# 912998  2017-12-30     10
# 912999  2017-12-31     10
#
# [901673 rows x 2 columns]

# %%
data.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000
